# %%
from utils.experiment import Experiment, Part, Box

# %%
exp2 = Experiment("data/participant_01/experiment_csv_01.csv")
exp2.boxes_to_csv("data/sentence_position_def.csv")
# Out:
# Saved 192 boxes to data/sentence_position_def.csv

# %%
# Out:
# {'part1': [<utils.Box object at 0x00000235C52B11C0>, <utils.Box object at 0x00000235C52B0C20>, <utils.Box object at 0x00000235C52B0B90>, <utils.Box object at 0x00000235C52B1010>], 'part2': [<utils.Box object at 0x00000235C52B0CB0>, <utils.Box object at 0x00000235C52B0A70>]}
# {'top': 236.0, 'bottom': 324.0, 'left': 115.0, 'right': 1805.0}
# ...
# {'top': 324.0, 'bottom': 412.0, 'left': 154.0, 'right': 1766.0}
# ...
# {'top': 412.0, 'bottom': 500.0, 'left': 102.0, 'right': 1818.0}
# ...
# {'top': 500.0, 'bottom': 588.0, 'left': 791.0, 'right': 1129.0}
# ...
